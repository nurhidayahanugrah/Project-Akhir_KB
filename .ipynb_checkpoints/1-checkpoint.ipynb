# %%
import tensorflow as tf
from keras_preprocessing.image import ImageDataGenerator

# %%
train_path =r'Handbags Classification/Train Dataset'
val_path =r'Handbags Classification/Valid Dataset'

# %%
train_datagen = ImageDataGenerator(rescale=1/255)
train_generator = train_datagen.flow_from_directory(
    train_path,
    batch_size=32, 
    class_mode='categorical',
    target_size=(150,150)
)

val_datagen = ImageDataGenerator(rescale=1/255)
val_generator = val_datagen.flow_from_directory(
    val_path,
    batch_size=32, 
    class_mode='categorical',
    target_size=(150,150)
)
# Out:
# Found 2749 images belonging to 5 classes.
# Found 500 images belonging to 5 classes.

# %%
image, label = train_generator.next()

# %%
labels = ['Backpack Min Bag', 'Belt Bag', 'Duffle Bag', 'Shoulder Bag',
       'Tote Bag']

# %%
data = 3
plt.imshow(image[data])
plt.title(labels[tf.argmax(label[data])])
plt.show()

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150,150, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation = 'relu'),
    tf.keras.layers.Dense(5, activation='softmax')

])

# %%
# model = tf.keras.Sequential([
#     tf.keras.layers.Dense(512, activation = 'relu', input_dim = 784), 
#     tf.keras.layers.Dense(256, activation = 'relu'),
#     tf.keras.layers.Dense(124, activation = 'relu'),
#     tf.keras.layers.Dense(10, activation = 'softmax')
# ])
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 148, 148, 32)      896
#
#  max_pooling2d_5 (MaxPooling  (None, 74, 74, 32)       0
#  2D)
#
#  flatten_5 (Flatten)         (None, 175232)            0
#
#  dense_19 (Dense)            (None, 64)                11214912
#
#  dense_20 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 11,216,133
# Trainable params: 11,216,133
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer= 'adam',
    loss= 'categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_generator,
    epochs=10,
    validation_data = val_generator
)
# Out:
# Epoch 1/10
# 86/86 [==============================] - 30s 348ms/step - loss: 0.0185 - accuracy: 0.9949 - val_loss: 2.5076 - val_accuracy: 0.5340
# Epoch 2/10
# 86/86 [==============================] - 29s 333ms/step - loss: 0.0268 - accuracy: 0.9945 - val_loss: 2.8828 - val_accuracy: 0.5460
# Epoch 3/10
# 86/86 [==============================] - 29s 337ms/step - loss: 0.0494 - accuracy: 0.9931 - val_loss: 2.6865 - val_accuracy: 0.5520
# Epoch 4/10
# 86/86 [==============================] - 32s 367ms/step - loss: 0.0568 - accuracy: 0.9935 - val_loss: 2.1855 - val_accuracy: 0.5580
# Epoch 5/10
# 86/86 [==============================] - 29s 343ms/step - loss: 0.0266 - accuracy: 0.9945 - val_loss: 2.5122 - val_accuracy: 0.5580
# Epoch 6/10
# 86/86 [==============================] - 29s 340ms/step - loss: 0.0271 - accuracy: 0.9942 - val_loss: 2.5206 - val_accuracy: 0.5600
# Epoch 7/10
# 86/86 [==============================] - 29s 334ms/step - loss: 0.0168 - accuracy: 0.9949 - val_loss: 2.6915 - val_accuracy: 0.5580
# Epoch 8/10
# 86/86 [==============================] - 30s 347ms/step - loss: 0.0185 - accuracy: 0.9945 - val_loss: 2.4176 - val_accuracy: 0.5580
# Epoch 9/10
# 86/86 [==============================] - 30s 354ms/step - loss: 0.0156 - accuracy: 0.9960 - val_loss: 2.5968 - val_accuracy: 0.5500
# Epoch 10/10
# 86/86 [==============================] - 29s 336ms/step - loss: 0.0377 - accuracy: 0.9931 - val_loss: 2.4385 - val_accuracy: 0.5640

# %%
#train
y_acctrain = history.history['accuracy']
y_accval = history.history['val_accuracy']

#validation
y_losstrain = history.history['loss']
y_lossval = history.history['val_loss']

#epoch
x_ = range(len(y_acctrain))

# %%
plt.figure(1, figsize=(5,4))
plt.plot(x_, y_acctrain, c='r', label='Training')
plt.plot(x_, y_accval, c='b', label='Validation')
plt.title('Akurasi')
plt.xlabel('Epochs')
plt.ylabel('Akurasi')
plt.legend()

plt.figure(2, figsize=(5,4))
plt.plot(x_[3:], y_losstrain[3:], c='r', label='Training')
plt.plot(x_[3:], y_lossval[3:], c='b', label='Validation')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
